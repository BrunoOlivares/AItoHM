# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoOlivares/AItoHM/blob/main/aula01_preenchido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de texto de fontes desestruturadas e Web
#
# ## Aula 01 - PDFs
#
# Nesta aula iremos trabalhar com extração de informações a partir de PDFs utilizando bibliotecas do Python.
#
# ## O que são arquivos PDF?
#
# O PDF, ou *Portable Document Format*, é um formato de arquivo criado pela Adobe em 1993. O principal objetivo em utilizar um PDF envolve permitir que um documento seja lido de forma independente do hardware ou sistema operacional utilizado pelo usuário. Também, sem a necessidade de possuir instalado o programa utilizado para criar o documento.
#
# <img src="https://atd-insper.s3.us-east-2.amazonaws.com/aula02/pdf_adobe.jpg">
#
# Documentos PDF são padronizados conforme a ISO 32000. Os arquivos PDF geralmente incluem:
# - informações textuais
# - imagens vetoriais
# - imagens bitmap
#
# Eles são distribuídos principalmente com foco em leitura, ou seja, ao criar um DOC no Microsoft Word, repassamos o `arquivo.DOCX` para pessoas que necessitem editá-lo.
#
# Para as pessoas que apenas necessitam ler as informações do documento, transformamos o DOC em PDF e enviamos neste formato!
#
#
# ## Qual a importância de extrair informações de PDFs?
#
# Arquivos PDF são criados com foco principal sendo a interação entre organizações e pessoas (uma cria, a outra lê).
#
# Em um cenário ideal, as informações contidas no PDF também estariam disponíveis em um ambiente estruturado e de fácil recuperação (ex: sistema de gerenciamento de banco de dados). Entretanto, muitas vezes a única forma disponível para acessos aos dados é o próprio arquivo PDF, por exemplo: editais, relatórios governamentais, lista de lojas, relatórios de desempenho, etc.
#
# Nesta aula, iremos aprender como extrair informações de PDFs, tabulares ou não. Além disso, veremos como utilizar recursos do Python para armazenar e analisar estes dados.
#
# ## Biblioteca *camelot*
# Para os dados tabulares, a principal biblioteca que utilizaremos será a camelot (https://camelot-py.readthedocs.io/en/master/).
# Para utilizá-la, será necessário instalar algumas dependências. Como você está utilizando o **Google Colab**, execute os seguintes comandos (execute esta célula):

# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !pip install 'PyPDF2<3.0'
# !apt install ghostscript python3-tk
# Out:
# Collecting ghostscript
#   Downloading ghostscript-0.8.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading ghostscript-0.8.1-py3-none-any.whl (25 kB)
# Installing collected packages: ghostscript
# Successfully installed ghostscript-0.8.1
# Collecting camelot-py[cv]
#   Downloading camelot_py-1.0.9-py3-none-any.whl.metadata (9.8 kB)
# WARNING: camelot-py 1.0.9 does not provide the extra 'cv'
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (8.3.1)
# Requirement already satisfied: chardet>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (5.2.0)
# Requirement already satisfied: numpy>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (2.0.2)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (3.1.5)
# Collecting pdfminer-six>=20240706 (from camelot-py[cv])
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting pypdf<6.0,>=4.0 (from camelot-py[cv])
#   Downloading pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (2.2.2)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (0.9.0)
# Requirement already satisfied: opencv-python-headless>=4.7.0.68 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (4.13.0.92)
# Collecting pypdfium2>=4 (from camelot-py[cv])
#   Downloading pypdfium2-5.5.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=10.4.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py[cv]) (11.3.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.0->camelot-py[cv]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->camelot-py[cv]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->camelot-py[cv]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->camelot-py[cv]) (2025.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py[cv]) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py[cv]) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py[cv]) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.2->camelot-py[cv]) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py[cv]) (3.0)
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 27.5 MB/s eta 0:00:00
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.2/313.2 kB 9.6 MB/s eta 0:00:00
# Downloading pypdfium2-5.5.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 19.0 MB/s eta 0:00:00
# Downloading camelot_py-1.0.9-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pypdf, pdfminer-six, camelot-py
# Successfully installed camelot-py-1.0.9 pdfminer-six-20260107 pypdf-5.9.0 pypdfium2-5.5.0
# Collecting excalibur-py
#   Downloading excalibur_py-1.0.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: camelot-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (1.0.9)
# Collecting celery>=4.1.1 (from excalibur-py)
#   Downloading celery-5.6.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (8.3.1)
# Collecting configparser>=7.1.0 (from excalibur-py)
#   Downloading configparser-7.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: Flask>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (3.1.2)
# Requirement already satisfied: SQLAlchemy>=1.2.12 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (2.0.46)
# Requirement already satisfied: Werkzeug>=3.1.3 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (3.1.5)
# Requirement already satisfied: pypdfium2>=4 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (5.5.0)
# Requirement already satisfied: Pillow>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from excalibur-py) (11.3.0)
# Requirement already satisfied: chardet>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (5.2.0)
# Requirement already satisfied: numpy>=1.26.1 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (2.0.2)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (3.1.5)
# Requirement already satisfied: pdfminer-six>=20240706 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (20260107)
# Requirement already satisfied: pypdf<6.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (5.9.0)
# Requirement already satisfied: pandas>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (2.2.2)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (0.9.0)
# Requirement already satisfied: opencv-python-headless>=4.7.0.68 in /usr/local/lib/python3.12/dist-packages (from camelot-py>=1.0.0->excalibur-py) (4.13.0.92)
# Collecting billiard<5.0,>=4.2.1 (from celery>=4.1.1->excalibur-py)
#   Downloading billiard-4.2.4-py3-none-any.whl.metadata (4.8 kB)
# Collecting kombu>=5.6.0 (from celery>=4.1.1->excalibur-py)
#   Downloading kombu-5.6.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting vine<6.0,>=5.1.0 (from celery>=4.1.1->excalibur-py)
#   Downloading vine-5.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting click-didyoumean>=0.3.0 (from celery>=4.1.1->excalibur-py)
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting click-repl>=0.2.0 (from celery>=4.1.1->excalibur-py)
#   Downloading click_repl-0.3.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: click-plugins>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from celery>=4.1.1->excalibur-py) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from celery>=4.1.1->excalibur-py) (2.9.0.post0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from celery>=4.1.1->excalibur-py) (5.3.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=3.1.0->excalibur-py) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask>=3.1.0->excalibur-py) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from Flask>=3.1.0->excalibur-py) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask>=3.1.0->excalibur-py) (3.0.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=1.2.12->excalibur-py) (3.3.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=1.2.12->excalibur-py) (4.15.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /usr/local/lib/python3.12/dist-packages (from click-repl>=0.2.0->celery>=4.1.1->excalibur-py) (3.0.52)
# Collecting amqp<6.0.0,>=5.1.1 (from kombu>=5.6.0->celery>=4.1.1->excalibur-py)
#   Downloading amqp-5.3.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.12/dist-packages (from kombu>=5.6.0->celery>=4.1.1->excalibur-py) (2025.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kombu>=5.6.0->celery>=4.1.1->excalibur-py) (26.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.1.0->camelot-py>=1.0.0->excalibur-py) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.2->camelot-py>=1.0.0->excalibur-py) (2025.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py>=1.0.0->excalibur-py) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer-six>=20240706->camelot-py>=1.0.0->excalibur-py) (43.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->celery>=4.1.1->excalibur-py) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py>=1.0.0->excalibur-py) (2.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery>=4.1.1->excalibur-py) (0.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py>=1.0.0->excalibur-py) (3.0)
# Downloading excalibur_py-1.0.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 15.4 MB/s eta 0:00:00
# Downloading celery-5.6.2-py3-none-any.whl (445 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.5/445.5 kB 34.1 MB/s eta 0:00:00
# Downloading configparser-7.2.0-py3-none-any.whl (17 kB)
# Downloading billiard-4.2.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 8.4 MB/s eta 0:00:00
# Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Downloading kombu-5.6.2-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.2/214.2 kB 22.3 MB/s eta 0:00:00
# Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Downloading amqp-5.3.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: vine, configparser, click-didyoumean, billiard, click-repl, amqp, kombu, celery, excalibur-py
# Successfully installed amqp-5.3.1 billiard-4.2.4 celery-5.6.2 click-didyoumean-0.3.1 click-repl-0.3.0 configparser-7.2.0 excalibur-py-1.0.1 kombu-5.6.2 vine-5.1.0
# Collecting PyPDF2<3.0
#   Downloading pypdf2-2.12.1-py3-none-any.whl.metadata (6.6 kB)
# Downloading pypdf2-2.12.1-py3-none-any.whl (222 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.12.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   blt fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 poppler-data tk8.6-blt2.5
# Suggested packages:
#   blt-demo fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum tix python3-tk-dbg
# The following NEW packages will be installed:
#   blt fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 poppler-data python3-tk
#   tk8.6-blt2.5
# 0 upgraded, 13 newly installed, 0 to remove and 2 not upgraded.
# Need to get 17.5 MB of archives.
# After this operation, 66.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 tk8.6-blt2.5 amd64 2.5.3+dfsg-4.1build2 [643 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 blt amd64 2.5.3+dfsg-4.1build2 [4,838 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.13 [753 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.13 [5,032 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.13 [49.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-tk amd64 3.10.8-1~22.04 [110 kB]
# Fetched 17.5 MB in 2s (8,627 kB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package tk8.6-blt2.5.
# Preparing to unpack .../02-tk8.6-blt2.5_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Selecting previously unselected package blt.
# Preparing to unpack .../03-blt_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking blt (2.5.3+dfsg-4.1build2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../04-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../05-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../06-libgs9-common_9.55.0~dfsg1-0ubuntu5.13_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../07-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../08-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../09-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../10-libgs9_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../11-ghostscript_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package python3-tk:amd64.
# Preparing to unpack .../12-python3-tk_3.10.8-1~22.04_amd64.deb ...
# Unpacking python3-tk:amd64 (3.10.8-1~22.04) ...
# Setting up tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up blt (2.5.3+dfsg-4.1build2) ...
# Setting up python3-tk:amd64 (3.10.8-1~22.04) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# Lembra-se de executar o import novamente quando instalar bibliotecas!

# %% [markdown]
# ## Importando as bibliotecas necessárias
#
# Aqui, iremos importar as bibliotecas que utilizaremos na aula

# %%
import os
import pandas as pd
import numpy as np
import camelot
import missingno as mn
import seaborn as sb
import plotly.express as px
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# Caso obtenha algum erro, utilize o **!pip install** para instalar a biblioteca ausente!

# %%
# Exemplo (remover # da proxima linha se preciso)
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in /usr/local/lib/python3.12/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from missingno) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from missingno) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from missingno) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn->missingno) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->missingno) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn->missingno) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.17.0)

# %% [markdown]
# Vamos conferir em qual diretório estamos executando o notebook?

# %%
print('O seu notebook está no diretório')
print(os.getcwd())
# Out:
# O seu notebook está no diretório
# /content

# %% [markdown]
# ## Lendo um PDF
#
# Para realizar a leitura dos dados tabulares, vamos utilizar a biblioteca **camelot**:

# %%
pdf_path = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula02/stores.pdf'
tabelas = camelot.read_pdf(pdf_path)
tabelas
# Out:
# <TableList n=1>

# %% [markdown]
# Podemos ver que encontramos uma tabela no documento.
#
# Agora, vamos conferir o *parsing report* do *camelot* para esta tabela:

# %%
print(tabelas[0].parsing_report)
# Out:
# {'accuracy': 100.0, 'whitespace': 8.17, 'order': 1, 'page': 1}

# %% [markdown]
# E podemos obter um *DataFrame* do *pandas* com os dados desta tabela:
#
# Depois iremos aprender o que mais podemos fazer com este DataFrame!

# %%
df = tabelas[0].df
df
# Out:
#          0             1               2                 3        4   \
# 0   CodLoja      TipoLoja          Cidade  CustoOperacional  NumFunc
# 1       L01   Eletrônicos       São Paulo          9,893.24       20
# 2       L02    Acessórios       São Paulo          4,048.26       16
# 3       L03  Games e Info       São Paulo          5,035.14       10
# 4       L04  Games e Info       São Paulo          5,001.69        6
# 5       L05  Games e Info       São Paulo          4,953.57        6
# 6       L06    Acessórios       São Paulo          3,982.36       11
# 7       L07    Acessórios       São Paulo          3,918.66        3
# 8       L08   Eletrônicos       São Paulo          9,987.32       25
# 9       L09   Eletrônicos  Rio de Janeiro          9,530.83       22
# 10      L10    Acessórios  Rio de Janeiro          3,595.69       15
# 15   2,950.75           67.19             4.88            0
# 16   8,987.39           11.27             2.62            0
# 17   9,492.90           12.09             0.44            0
# 18   6,457.83          125.78             6.72            1            1
# 19   5,963.79           23.78             4.95            1            1
# 20   5,997.23           23.53             2.64            1            1
# 21   2,982.56           11.69             3.11            1            0
# 22   3,439.24           85.07             6.50            0            0
# 23   3,437.89           72.61             0.18            0            0
# 24   9,534.84           11.94             5.86            0            0
# 25   8,527.92           10.68             6.47            0            0
# 26   5,510.36           97.85             7.79            1            1
# 27   4,979.04           19.65             2.83            0            1
# 28   4,949.32           18.82             7.33            1            1
# 29   4,970.17           19.43             7.19            0            1
# 30   5,490.35          109.00             5.04            0            1
# 31   5,519.87          115.48             5.88            0            1
# 32  11,521.47           14.37             8.01            1            1
# 33   3,449.18           14.19             4.38            1            0
# 34   9,948.74           12.17             5.43            1            0
# 35   2,963.19           65.22             3.33            0            0
# 36   6,018.82          102.51            15.69            1            1
# 37  12,120.64           15.28             7.24            0            1
# 38   5,927.85          115.13             3.37            1            1
# 39   3,043.45           59.94             2.43            1            0
# 40   9,003.72           11.10             2.41            1            0
# 41   9,053.25           11.11             6.34            1            0
# 42   2,950.96           52.99             3.02            0            0
# 43   2,950.84           12.02             1.28            0            0
# 44   5,944.90           25.48             0.57            0            1
# 45   6,019.70           23.06             9.76            0            1
# 46   6,527.32          120.50             4.72            0            1
# 47   3,501.24           64.26             0.12            1            0
# 48   9,522.54           11.58             2.97            1            0
# 49   1,981.24            7.57             6.59            1            0
# 50   5,483.42          110.27             2.79            0            1
# 51   5,505.55          105.27             4.94            0            1
#
#         10          11
# 0   Perfil  LojaCentro
# 1        1
# 2        4
# 3        3
# 4        4
# 5        1
# 6        4
# 7        4
# 8        3
# 9        4
# 10       1
# 11       2
# 12       4
# 13       1
# 14       2
# 15       2
# 16       2           1
# 17       3
# 18       1
# 19       1
# 20       3
# 21       3
# 22       1
# 23       2
# 24       2
# 25       3
# 26       3
# 27       4
# 28       3
# 29       2
# 30       3
# 31       1           1
# 32       4           0
# 33       4
# 34       3
# 35       3
# 36       4
# 37       2
# 38       3
# 39       4
# 40       2
# 41       4
# 42       2
# 43       2
# 44       2
# 45       4
# 46       2
# 47       4
# 48       4
# 49       4
# 50       2
# 51       1

# %% [markdown]
# A funcionalidade de *read_pdf* do *camelot* permite especificar diversos parâmetros. Por exemplo, podemos ler apenas a página 2:

# %%
pdf_path = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula02/stores.pdf'
tabelas = camelot.read_pdf(pdf_path, pages = '2')
df_pg2 = tabelas[0].df
df_pg2
# Out:
#      0             1               2          3   4          5       6   \
# 0   L52   Eletrônicos       São Paulo  10,002.37  30  12,990.53   16.43
# 1   L53   Eletrônicos       São Paulo  10,129.94  24  10,003.34   12.74
# 2   L54    Acessórios  Rio de Janeiro   3,458.45   8   3,032.39   57.07
# 3   L55  Games e Info  Rio de Janeiro   4,533.89  10   5,488.57   20.66
# 4   L56  Games e Info  Rio de Janeiro   4,549.74   7   5,552.39   21.21
# 5   L57  Games e Info        Brasília   4,035.74   7   5,983.45   22.36
# 14   4.82  0  1  1
# 15   2.53  1  1  2
# 16   0.09  0  0  3
# 17  10.90  1  1  4
# 18   8.29  1  0  2
# 19   5.19  0  1  4
# 20   1.46  1  1  4
# 21   8.83  1  0  1
# 22   5.02  0  1  4
# 23   3.13  1  1  3
# 24   8.23  1  0  3
# 25   5.89  0  1  3
# 26   9.59  1  1  3
# 27   6.65  1  0  4
# 28   8.41  0  1  3
# 29   9.46  1  1  4
# 30   2.97  1  0  3
# 31   6.86  0  1  4
# 32   8.56  1  1  4
# 33   1.54  1  0  3
# 34   3.88  1  1  2
# 35   0.51  1  1  4
# 36  10.90  1  1  4
# 37   8.05  0  1  3
# 38   3.64  0  1  4
# 39   3.73  0  1  1

# %% [markdown]
# # Múltiplas tabelas em um mesmo arquivo
#
# Imagem de exemplo com múltiplas tabelas em uma mesma página:
# <img src="https://atd-insper.s3.us-east-2.amazonaws.com/aula02/relatorio_aula02.png">

# %%
pdf_path = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula02/relatorio.pdf'
tab_rep = camelot.read_pdf(pdf_path)
tab_rep
# Out:
# <TableList n=2>

# %% [markdown]
# Podemos perceber que foram encontradas duas tabelas no arquivo.

# %%
df_relat1 = tab_rep[0].df
df_relat1
# Out:
#         0     1     2     3
# 0           Jan   Fev   Mar
# 1  Loja 1  5501  6031  7212
# 2  Loja 2  8007  8052  7301
# 3  Loja 3  6001  5041  8327

# %%
df_relat2 = tab_rep[1].df
df_relat2
# Out:
#               0       1     2     3     4
# 0      Vendedor    Loja   Jan   Fev   Mar
# 1       João S.  Loja 1  5501  6031  7212
# 2       Igor M.  Loja 2  8007  8052  7301
# 3      Celso T.  Loja 3  6001  5041  8327
# 4        Ana S.  Loja 1  5501  6031  7212
# 5      Tiago B.  Loja 2  8007  8052  7301
# 6     Helena W.  Loja 3  6001  5041  8327
# 7       José K.  Loja 1  5501  6031  7212
# 8      Bruna D.  Loja 2  8007  8052  7301
# 9   Vinicius G.  Loja 3  6001  5041  8327
# 10     Pedro T.  Loja 1  5501  6031  7212
# 11       Ana P.  Loja 2  8007  8052  7301
# 12     Elder N.  Loja 3  6001  5041  8327

# %% [markdown]
# Utilizando o report gráfico para analisar as extrações:

# %%
camelot.plot(tab_rep[1], kind='text').show()

# %%
camelot.plot(tab_rep[0], kind='contour').show()

# %% [markdown]
# ## Primeiro contato com o *pandas*
#
# Agora, vamos aprender como utilizar recursos da biblioteca *pandas*.

# %%
pdf_path = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula02/stores.pdf'
tabelas = camelot.read_pdf(pdf_path, split_text=True, pages='1-end')
tabelas
# Out:
# <TableList n=2>

# %%
type(tabelas[0].df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Iremos concatenar dois DataFrames:

# %%
df0 = tabelas[0].df
df1 = tabelas[1].df

df_all = pd.concat([df0, df1], axis=0)
df_all
# Out:
#          0             1               2                 3        4   \
# 0   CodLoja      TipoLoja          Cidade  CustoOperacional  NumFunc
# 1       L01   Eletrônicos       São Paulo          9,893.24       20
# 2       L02    Acessórios       São Paulo          4,048.26       16
# 3       L03  Games e Info       São Paulo          5,035.14       10
# 4       L04  Games e Info       São Paulo          5,001.69        6
# ..      ...           ...             ...               ...      ...
# 35      L87    Acessórios  Rio de Janeiro          3,539.74       15
# 36      L88   Eletrônicos  Rio de Janeiro          9,548.37       19
# 37      L89   Eletrônicos  Rio de Janeiro          9,502.63       26
# 38      L90  Games e Info       São Paulo          4,923.23       11
# 39      L91    Acessórios       São Paulo          3,957.80       12
#
#            5               6                7            8            9   \
# 0      FatDia  NumClientesDia  CustoAquiPorCli  LojaPropria  VendeOnline
# 1   12,942.78           16.50             3.91            0            1
# 2    7,095.50          145.92            10.69            0            1
# 3    6,602.59           25.53             4.46            1            1
# 4    3,455.80           13.77             6.30            1            0
# ..        ...             ...              ...          ...          ...
# 35   6,003.37          133.35             0.51            1            1
# 36  11,953.24           14.84            10.90            1            1
# 37  12,057.17           14.91             8.05            0            1
# 38   6,471.47           24.48             3.64            0            1
# 39   7,028.76          140.77             3.73            0            1
#
#         10          11
# 0   Perfil  LojaCentro
# 1        1
# 2        4
# 3        3
# 4        4
# ..     ...         ...
# 35       4
# 36       4
# 37       3
# 38       4
# 39       1
#
# [92 rows x 12 columns]

# %% [markdown]
# podemos exibir apenas o início do nosso DataFrame, para não ter a tela toda poluída com dados

# %%
df.head()
# Out:
#         0             1          2                 3        4          5   \
# 0  CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc     FatDia
# 1      L01   Eletrônicos  São Paulo          9,893.24       20  12,942.78
# 2      L02    Acessórios  São Paulo          4,048.26       16   7,095.50
# 3      L03  Games e Info  São Paulo          5,035.14       10   6,602.59
# 4      L04  Games e Info  São Paulo          5,001.69        6   3,455.80
#
#                6                7            8            9       10  \
# 0  NumClientesDia  CustoAquiPorCli  LojaPropria  VendeOnline  Perfil
# 1           16.50             3.91            0            1       1
# 2          145.92            10.69            0            1       4
# 3           25.53             4.46            1            1       3
# 4           13.77             6.30            1            0       4
#
#            11
# 0  LojaCentro
# 1
# 2
# 3
# 4

# %% [markdown]
# ou os últimos:

# %%
df.tail()
# Out:
#      0             1               2         3   4         5       6     7   \
# 47  L47    Acessórios        Brasília  2,996.18   8  3,501.24   64.26  0.12
# 48  L48   Eletrônicos        Brasília  8,996.01  17  9,522.54   11.58  2.97
# 49  L49  Games e Info  Belo Horizonte  4,001.27   5  1,981.24    7.57  6.59
# 50  L50    Acessórios  Belo Horizonte  3,042.01   9  5,483.42  110.27  2.79
# 51  L51    Acessórios  Belo Horizonte  3,026.23  14  5,505.55  105.27  4.94
#
#    8  9  10 11
# 47  1  0  4
# 48  1  0  4
# 49  1  0  4
# 50  0  1  2
# 51  0  1  1

# %% [markdown]
# é possível também especificar o número de linhas

# %%
df.head(2)
# Out:
#         0            1          2                 3        4          5   \
# 0  CodLoja     TipoLoja     Cidade  CustoOperacional  NumFunc     FatDia
# 1      L01  Eletrônicos  São Paulo          9,893.24       20  12,942.78
#
#                6                7            8            9       10  \
# 0  NumClientesDia  CustoAquiPorCli  LojaPropria  VendeOnline  Perfil
# 1           16.50             3.91            0            1       1
#
#            11
# 0  LojaCentro
# 1

# %% [markdown]
# Perceberam que o nome das colunas ficou na primeira linha?
#
# Vamos renomear as colunas do DataFrame:

# %%
df.columns = ['CodLoja', 'TipoLoja', 'Cidade', 'CustoOperacional','NumFunc', 'FatDia',
              'NumClientesDia', 'CustoAquiPorCli', 'LojaPropria', 'VendeOnline', 'Perfil', 'LojaCentro']
df.head(3)
# Out:
#    CodLoja     TipoLoja     Cidade  CustoOperacional  NumFunc     FatDia  \
# 0  CodLoja     TipoLoja     Cidade  CustoOperacional  NumFunc     FatDia
# 1      L01  Eletrônicos  São Paulo          9,893.24       20  12,942.78
# 2      L02   Acessórios  São Paulo          4,048.26       16   7,095.50
#
#    NumClientesDia  CustoAquiPorCli  LojaPropria  VendeOnline  Perfil  \
# 0  NumClientesDia  CustoAquiPorCli  LojaPropria  VendeOnline  Perfil
# 1           16.50             3.91            0            1       1
# 2          145.92            10.69            0            1       4
#
#    LojaCentro
# 0  LojaCentro
# 1
# 2

# %% [markdown]
# e agora vamos remover a primeira linha

# %%
# Comando para remover a primeira linha aqui
df.drop(0, axis=0, inplace=True)

df.head(3)
# Out:
#   CodLoja      TipoLoja     Cidade CustoOperacional NumFunc     FatDia  \
# 1     L01   Eletrônicos  São Paulo         9,893.24      20  12,942.78
# 2     L02    Acessórios  São Paulo         4,048.26      16   7,095.50
# 3     L03  Games e Info  São Paulo         5,035.14      10   6,602.59
#
#   NumClientesDia CustoAquiPorCli LojaPropria VendeOnline Perfil LojaCentro
# 1          16.50            3.91           0           1      1
# 2         145.92           10.69           0           1      4
# 3          25.53            4.46           1           1      3

# %% [markdown]
# Agora, vamos conferir os tipos de dados das colunas.

# %%
df.dtypes
# Out:
# CodLoja             object
# TipoLoja            object
# Cidade              object
# CustoOperacional    object
# NumFunc             object
# FatDia              object
# NumClientesDia      object
# CustoAquiPorCli     object
# LojaPropria         object
# VendeOnline         object
# Perfil              object
# LojaCentro          object
# dtype: object

# %% [markdown]
# Vamos alterar as colunas numéricas:

# %%
df
# Out:
#    CodLoja      TipoLoja          Cidade CustoOperacional NumFunc     FatDia  \
# 1      L01   Eletrônicos       São Paulo         9,893.24      20  12,942.78
# 2      L02    Acessórios       São Paulo         4,048.26      16   7,095.50
# 3      L03  Games e Info       São Paulo         5,035.14      10   6,602.59
# 4      L04  Games e Info       São Paulo         5,001.69       6   3,455.80
# 5      L05  Games e Info       São Paulo         4,953.57       6   3,515.88
# 6      L06    Acessórios       São Paulo         3,982.36      11   4,009.59
# 7      L07    Acessórios       São Paulo         3,918.66       3   4,041.81
# 8      L08   Eletrônicos       São Paulo         9,987.32      25   9,948.98
# 9      L09   Eletrônicos  Rio de Janeiro         9,530.83      22   8,963.34
# 10     L10    Acessórios  Rio de Janeiro         3,595.69      15   3,046.12
# 11     L11  Games e Info  Rio de Janeiro         4,435.76       8   2,462.53
# 12     L12  Games e Info  Rio de Janeiro         4,491.96       1   2,568.48
# 13     L13  Games e Info  Rio de Janeiro         4,454.46       4   2,448.07
# 14     L14    Acessórios  Rio de Janeiro         3,469.57       8   2,975.24
# 15     L15    Acessórios  Rio de Janeiro         3,560.35      11   2,950.75
# 16     L16   Eletrônicos  Rio de Janeiro         9,641.85      25   8,987.39
# 17     L17   Eletrônicos        Brasília         9,031.83      17   9,492.90
# 18     L18    Acessórios        Brasília         3,002.45      11   6,457.83
# 22          85.07            6.50           0           0      1
# 23          72.61            0.18           0           0      2
# 24          11.94            5.86           0           0      2
# 25          10.68            6.47           0           0      3
# 26          97.85            7.79           1           1      3
# 27          19.65            2.83           0           1      4
# 28          18.82            7.33           1           1      3
# 29          19.43            7.19           0           1      2
# 30         109.00            5.04           0           1      3
# 31         115.48            5.88           0           1      1          1
# 32          14.37            8.01           1           1      4          0
# 33          14.19            4.38           1           0      4
# 34          12.17            5.43           1           0      3
# 35          65.22            3.33           0           0      3
# 36         102.51           15.69           1           1      4
# 37          15.28            7.24           0           1      2
# 38         115.13            3.37           1           1      3
# 39          59.94            2.43           1           0      4
# 40          11.10            2.41           1           0      2
# 41          11.11            6.34           1           0      4
# 42          52.99            3.02           0           0      2
# 43          12.02            1.28           0           0      2
# 44          25.48            0.57           0           1      2
# 45          23.06            9.76           0           1      4
# 46         120.50            4.72           0           1      2
# 47          64.26            0.12           1           0      4
# 48          11.58            2.97           1           0      4
# 49           7.57            6.59           1           0      4
# 50         110.27            2.79           0           1      2
# 51         105.27            4.94           0           1      1

# %%
df['CustoOperacional'] = df['CustoOperacional'].str.replace(',','').astype(float)
df['NumFunc'] = df['NumFunc'].astype(int)
df['FatDia'] = df['FatDia'].str.replace(',','').astype(float)
df['NumClientesDia'] = df['NumClientesDia'].astype(float)
df['CustoAquiPorCli'] = df['CustoAquiPorCli'].astype(float)

# %%
df.dtypes
# Out:
# CodLoja              object
# TipoLoja             object
# Cidade               object
# CustoOperacional    float64
# NumFunc               int64
# FatDia              float64
# NumClientesDia      float64
# CustoAquiPorCli     float64
# LojaPropria          object
# VendeOnline          object
# Perfil               object
# LojaCentro           object
# dtype: object

# %% [markdown]
# Agora, vamos definir as variáveis categóricas:

# %%
df['TipoLoja'] = df['TipoLoja'].astype('category')
df['Cidade'] = df['Cidade'].astype('category')

df['LojaPropria'] = df['LojaPropria'].astype('category')
df['VendeOnline'] = df['VendeOnline'].astype('category')
df['Perfil'] = df['Perfil'].astype('category')
df['LojaCentro'] = df['LojaCentro'].astype('category')

# %% [markdown]
# Assim, os tipos ficam:

# %%
df.dtypes
# Out:
# CodLoja               object
# TipoLoja            category
# Cidade              category
# CustoOperacional     float64
# NumFunc                int64
# FatDia               float64
# NumClientesDia       float64
# CustoAquiPorCli      float64
# LojaPropria         category
# VendeOnline         category
# Perfil              category
# LojaCentro          category
# dtype: object

# %% [markdown]
# O que temos até agora?!

# %%
df.head(2)
# Out:
#   CodLoja     TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01  Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02   Acessórios  São Paulo           4048.26       16   7095.50
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil LojaCentro
# 1           16.50             3.91           0           1      1
# 2          145.92            10.69           0           1      4

# %% [markdown]
# Quantas linhas (registros) e colunas?

# %%
df.shape
# Out:
# (51, 12)

# %% [markdown]
# ### Filtrando dados
# Vamos aprender como selecionar apenas parte dos registros?
#
# Vamos selecionar apenas as lojas da cidade de São Paulo:

# %%
df.loc[df['Cidade'] == 'São Paulo']
# Out:
#    CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 
# 46          120.50             4.72           0           1      2
# 47           64.26             0.12           1           0      4
# 50          110.27             2.79           0           1      2
# 51          105.27             4.94           0           1      1

# %% [markdown]
# Vamos trazer apenas as colunas TipoLoja e FatDia da cidade de São Paulo:

# %%
filtro_linhas = df['Cidade'] == 'São Paulo'
df.loc[filtro_linhas, ['TipoLoja', 'FatDia']]
# Out:
#         TipoLoja    FatDia
# 1    Eletrônicos  12942.78
# 2     Acessórios   7095.50
# 3   Games e Info   6602.59
# 4   Games e Info   3455.80
# 5   Games e Info   3515.88
# 6     Acessórios   4009.59
# 7     Acessórios   4041.81
# 8    Eletrônicos   9948.98
# 33  Games e Info   3449.18
# 34   Eletrônicos   9948.74

# %% [markdown]
# Agora, apenas as lojas com faturamento diário acima de 12.000,00:

# %%
df.loc[df['FatDia'] > 12000]
# Out:
#    CodLoja     TipoLoja          Cidade  CustoOperacional  NumFunc    FatDia  \
# 1      L01  Eletrônicos       São Paulo           9893.24       20  12942.78
# 37     L37  Eletrônicos  Rio de Janeiro           9539.08       22  12120.64
#
#     NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil LojaCentro
# 1            16.50             3.91           0           1      1
# 37           15.28             7.24           0           1      2

# %% [markdown]
# E as lojas de Acessórios que vendem até  3000?
#
# **Atenção!** Se está filtrando por duas colunas, sempre utilize parênteses para envolver os critérios `( ) & ( )`

# %%
df.loc[(df['FatDia'] <= 3000) & (df['TipoLoja'] == 'Acessórios')]
# Out:
#    CodLoja    TipoLoja          Cidade  CustoOperacional  NumFunc   FatDia  \
# 14     L14  Acessórios  Rio de Janeiro           3469.57        8  2975.24
# 15     L15  Acessórios  Rio de Janeiro           3560.35       11  2950.75
# 35     L35  Acessórios  Rio de Janeiro           3501.30        9  2963.19
# 42     L42  Acessórios  Rio de Janeiro           3547.89       11  2950.96
#
#     NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil LojaCentro
# 14           61.01             1.44           0           0      2
# 15           67.19             4.88           0                  2
# 35           65.22             3.33           0           0      3
# 42           52.99             3.02           0           0      2

# %% [markdown]
# E somente as colunas Cidade e CustoOperacional, mas mantendo todas as linhas?

# %%
df.loc[:, ['Cidade', 'CustoOperacional']]
# Out:
#             Cidade  CustoOperacional
# 1        São Paulo           9893.24
# 2        São Paulo           4048.26
# 3        São Paulo           5035.14
# 4        São Paulo           5001.69
# 5        São Paulo           4953.57
# 6        São Paulo           3982.36
# 7        São Paulo           3918.66
# 8        São Paulo           9987.32
# 9   Rio de Janeiro           9530.83
# 10  Rio de Janeiro           3595.69
# 11  Rio de Janeiro           4435.76
# 12  Rio de Janeiro           4491.96
# 13  Rio de Janeiro           4454.46
# 14  Rio de Janeiro           3469.57
# 15  Rio de Janeiro           3560.35
# 16  Rio de Janeiro           9641.85
# 17        Brasília           9031.83
# 18        Brasília           3002.45
# 19        Brasília           3999.40
# 20        Brasília           4010.42
# 21        Brasília           3988.16
# 22        Brasília           3006.73
# 23        Brasília           3007.95
# 24        Brasília           8988.92
# 25  Belo Horizonte           9011.65
# 26  Belo Horizonte           3042.13
# 27  Belo Horizonte           3999.32
# 28  Belo Horizonte           4019.81
# 29  Belo Horizonte           4006.37
# 30  Belo Horizonte           2995.99
# 49            7.57             6.59           1           0      4
# 50          110.27             2.79           0           1      2
# 51          105.27             4.94           0           1      1

# %% [markdown]
# Existe toda uma literatura e técnicas que podem ser utilizadas em *missing imputation*.
#
# Primeiro, vamos conferir se eles existem:

# %%
df.isna().sum()
# Out:
# CodLoja             0
# TipoLoja            0
# Cidade              0
# CustoOperacional    0
# NumFunc             0
# FatDia              0
# NumClientesDia      0
# CustoAquiPorCli     0
# LojaPropria         0
# VendeOnline         0
# Perfil              0
# LojaCentro          0
# dtype: int64

# %% [markdown]
# Estranho, não?
#
# Consegue identificar por que isto acontece?

# %% [markdown]
# R:

# %% [markdown]
# Vamos substituir as strings vazias por NaN (not a number)

# %%
df.replace('', np.nan, inplace=True)
# Out:
# /tmp/ipython-input-2271395264.py:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df.replace('', np.nan, inplace=True)

# %%
df.dtypes
# Out:
# CodLoja               object
# TipoLoja            category
# Cidade              category
# CustoOperacional     float64
# NumFunc                int64
# FatDia               float64
# NumClientesDia       float64
# CustoAquiPorCli      float64
# LojaPropria         category
# VendeOnline         category
# Perfil              category
# LojaCentro          category
# dtype: object

# %% [markdown]
# E contar os missings novamente:

# %%
df.isna().sum()
# Out:
# CodLoja              0
# TipoLoja             0
# Cidade               0
# CustoOperacional     0
# NumFunc              0
# FatDia               0
# NumClientesDia       0
# CustoAquiPorCli      0
# LojaPropria          0
# VendeOnline          3
# Perfil               0
# LojaCentro          48
# dtype: int64

# %% [markdown]
# Vamos utilizar a biblioteca *missingno* para produzir algo mais visual?!

# %%
mn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# Quais colunas possuem missings?

# %% [markdown]
# R: VendeOnline e LojaCentro

# %% [markdown]
# Como podemos corrigir?!

# %% [markdown]
# R: Dependendo da quantidade de Nan encontrados, a coluna pode ser completamente deletada. Caso contrário, algum valor arbitrário mas coerente pode ser utilizado para preencher as lacunas pontuais de Nan

# %% [markdown]
# Vamos remover, da nossa análise, a última coluna do dataframe:

# %%
df.drop('LojaCentro', axis=1, inplace=True)

df.head()
# Out:
#   CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01   Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02    Acessórios  São Paulo           4048.26       16   7095.50
# 3     L03  Games e Info  São Paulo           5035.14       10   6602.59
# 4     L04  Games e Info  São Paulo           5001.69        6   3455.80
# 5     L05  Games e Info  São Paulo           4953.57        6   3515.88
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil
# 1           16.50             3.91           0           1      1
# 2          145.92            10.69           0           1      4
# 3           25.53             4.46           1           1      3
# 4           13.77             6.30           1           0      4
# 5           13.87             2.09           0           0      1

# %% [markdown]
# E arbitrariamente preencher os missings em VendeOnline com 1:

# %%
df.loc[df['VendeOnline'].isna(), 'VendeOnline'] = '1'

# %% [markdown]
# Conferindo os missings novamente:

# %%
mn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Ordenando os dados
#
# Como conseguimos ordenar os dados?

# %%
df.sort_values(by='Cidade')
# Out:
#    CodLoja      TipoLoja          Cidade  CustoOperacional  NumFunc    FatDia  \
# 26     L26    Acessórios  Belo Horizonte           3042.13       11   5510.36
# 49     L49  Games e Info  Belo Horizonte           4001.27        5   1981.24
# 32     L32   Eletrônicos  Belo Horizonte           9087.42       24  11521.47
# 14           61.01             1.44           0           0      2
# 35           65.22             3.33           0           0      3
# 42           52.99             3.02           0           0      2
# 43           12.02             1.28           0           0      2
# 15           67.19             4.88           0           1      2
# 12           10.54             0.68           0           0      4
# 11            9.24             3.21           1           0      2
# 13            9.71             0.36           0           0      1
# 49            7.57             6.59           1           0      4

# %% [markdown]
# ### Criando tabelas de frequência
#
# Conseguimos contar as ocorrências? Por exemplo, e se quiséssemos saber quantas lojas existem em cada cidade?

# %%
df['Cidade'].value_counts()
# Out:
# Cidade
# Rio de Janeiro    16
# Brasília          14
# Belo Horizonte    11
# São Paulo         10
# Name: count, dtype: int64

# %% [markdown]
# E se quisessemos saber a porcentagem de lojas em cada cidade?

# %%
df['Cidade'].value_counts(normalize=True)
# Out:
# Cidade
# Rio de Janeiro    0.313725
# Brasília          0.274510
# Belo Horizonte    0.215686
# São Paulo         0.196078
# Name: proportion, dtype: float64

# %% [markdown]
# **Exercício 1** Qual a porcentagem de lojas que são de Eletrônicos?

# %%
df["TipoLoja"].value_counts(normalize = True)
# Out:
# TipoLoja
# Acessórios      0.411765
# Games e Info    0.333333
# Eletrônicos     0.254902
# Name: proportion, dtype: float64

# %% [markdown]
# **Exercício 2** Considerando apenas São Paulo, qual a porcentagem de lojas que são de Eletrônicos?

# %%
df1 = df.loc[df["Cidade"] == "São Paulo"]
df1["TipoLoja"].value_counts(normalize = True)
# Out:
# TipoLoja
# Games e Info    0.4
# Acessórios      0.3
# Eletrônicos     0.3
# Name: proportion, dtype: float64

# %% [markdown]
# Podemos exibir a tabela de frequências de forma gráfica?

# %%
cont = df['Cidade'].value_counts(normalize=True)
cont.plot.bar()
# Out:
# <Axes: xlabel='Cidade'>

# %%
cont
# Out:
# Cidade
# Rio de Janeiro    0.313725
# Brasília          0.274510
# Belo Horizonte    0.215686
# São Paulo         0.196078
# Name: proportion, dtype: float64

# %%
cont.reset_index()
# Out:
#            Cidade  proportion
# 0  Rio de Janeiro    0.313725
# 1        Brasília    0.274510
# 2  Belo Horizonte    0.215686
# 3       São Paulo    0.196078

# %%
dados = cont.reset_index()

px.bar(dados, x='Cidade', y='proportion',
       color='Cidade', title='Freq. Loja por Cidade')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35f6005c-0f49-4cbc-9c2d-0c55998b27bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35f6005c-0f49-4cbc-9c2d-0c55998b27bd")) {                    Plotly.newPlot(                        "35f6005c-0f49-4cbc-9c2d-0c55998b27bd",                        [{"alignmentgroup":"True","hovertemplate":"Cidade=%{x}\u003cbr\u003eproportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rio de Janeiro","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rio de Janeiro","offsetgroup":"Rio de Janeiro","orientation":"v","showlegend":true,"textposition":"auto","x":["Rio de Janeiro"],"xaxis":"x","y":[0.3137254901960784],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cidade=%{x}\u003cbr\u003eproportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brasília","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Brasília","offsetgroup":"Brasília","orientation":"v","showlegend":true,"textposition":"auto","x":["Brasília"],"xaxis":"x","y":[0.27450980392156865],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cidade=%{x}\u003cbr\u003eproportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Belo Horizonte","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Belo Horizonte","offsetgroup":"Belo Horizonte","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte"],"xaxis":"x","y":[0.21568627450980393],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cidade=%{x}\u003cbr\u003eproportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"São Paulo","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"São Paulo","offsetgroup":"São Paulo","orientation":"v","showlegend":true,"textposition":"auto","x":["São Paulo"],"xaxis":"x","y":[0.19607843137254902],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...

# %% [markdown]
# ### Medidas Resumo
#
# E se quiséssemos saber a média de faturamento por dia?

# %%
df['FatDia'].mean()
# Out:
# np.float64(5817.7682352941165)

# %% [markdown]
# E os valores máximo, mínimo e mediana?!

# %%
df['FatDia'].max()
# Out:
# 12942.78

# %%
df['FatDia'].min()
# Out:
# 1981.24

# %%
df['FatDia'].median()
# Out:
# 5505.55

# %% [markdown]
# Podemos resumir estas estatísticas em um único comando:

# %%
df.describe()
# Out:
#        CustoOperacional    NumFunc        FatDia  NumClientesDia  \
# count         51.000000  51.000000     51.000000       51.000000
# mean        5220.880000  12.254902   5817.768235       45.726471
# std         2558.841605   5.955982   2842.187368       41.217935
# min         2955.580000   1.000000   1981.240000        7.570000
# 25%         3514.590000   8.000000   3438.565000       12.055000
# 50%         4001.270000  11.000000   5505.550000       23.060000
# 75%         7012.030000  15.500000   7811.710000       72.825000
# max        10090.020000  25.000000  12942.780000      145.920000
#
#        CustoAquiPorCli
# count        51.000000
# mean          4.443922
# std           3.006598
# min           0.120000
# 25%           2.525000
# 50%           4.380000
# 75%           6.320000
# max          15.690000

# %% [markdown]
# ### Distribuição
#
# Faz sentido realizar uma contagem na variável de Faturamento?
#
# Podemos analisar a distribuição.

# %%
df['FatDia'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['FatDia'].plot.hist(bins=8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
px.histogram(df['FatDia'],
             labels={'value': 'Faturamento'},
             title = 'Distribuição do faturamento')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="954f48e5-802a-4d8c-954b-2590ef0dcadc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("954f48e5-802a-4d8c-954b-2590ef0dcadc")) {                    Plotly.newPlot(                        "954f48e5-802a-4d8c-954b-2590ef0dcadc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=FatDia\u003cbr\u003eFaturamento=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FatDia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"FatDia","offsetgroup":"FatDia","orientation":"v","showlegend":true,"x":[12942.78,7095.5,6602.59,3455.8,3515.88,4009.59,4041.81,9948.98,8963.34,3046.12,2462.53,2568.48,2448.07,2975.24,2950.75,8987.39,9492.9,6457.83,5963.79,5997.23,2982.56,3439.24,3437.89,9534.84,8527.92,5510.36,4979.04,4949.32,4970.17,5490.35,5519.87,11521.47,3449.18,9948.74,2963.19,6018.82,12120.64,5927.85,3043.45,9003.72,9053.25,2950.96,2950.84,5944.9,6019.7,6527.32,3501.24,9522.54,1981.24,5483.42,5505.55],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"o ...

# %%
df_hist = df.loc[:, ['TipoLoja', 'FatDia']]

px.histogram(df_hist, x = 'FatDia',
             color='TipoLoja', opacity=0.75)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa5f3648-57d5-454d-af3c-83bffeb3e762" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa5f3648-57d5-454d-af3c-83bffeb3e762")) {                    Plotly.newPlot(                        "fa5f3648-57d5-454d-af3c-83bffeb3e762",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TipoLoja=Eletrônicos\u003cbr\u003eFatDia=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eletrônicos","marker":{"color":"#636efa","opacity":0.75,"pattern":{"shape":""}},"name":"Eletrônicos","offsetgroup":"Eletrônicos","orientation":"v","showlegend":true,"x":[12942.78,9948.98,8963.34,8987.39,9492.9,9534.84,8527.92,11521.47,9948.74,12120.64,9003.72,9053.25,9522.54],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TipoLoja=Acessórios\u003cbr\u003eFatDia=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acessórios","marker":{"color":"#EF553B","opacity":0.75,"pattern":{"shape":""}},"name":"Acessórios","offsetgroup":"Acessórios","orientation":"v","showlegend":true,"x":[7095.5,4009.59,4041.81,3046.12,2975.24,2950.75,6457.83,3439.24,3437.89,5510.36,5490.35,5519.87,2963.19,6018.82,5927.85,3043.45,2950.96,6527.32,3501.24,5483.42,5505.55],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"TipoLoja=Games e Info\u003cbr\u003eFatDia=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Games e Info","marker":{"color":"#00cc96","opacity":0.75,"pattern":{"shape":""}},"name":"Games e Info","offsetgroup":"Games e Info","orientation":"v","showlegend":true,"x":[6602.59,3455.8,3515.88,2462.53,2568.48,2448.07,5963.79,5997.23,2982.56,4979.04,4949.32,4970.17,3449.18,2950.84,5944.9,6019.7,1981.24],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4603 ...

# %% [markdown]
# E como plotar diversos gráficos na mesma célula?

# %%
fig = plt.figure(figsize=(10, 6))

plt.subplot(2, 2, 1)
df['FatDia'].plot.hist()
plt.title('Faturamento Dia')

plt.subplot(2, 2, 2)
df['CustoOperacional'].plot.hist()
plt.title('Custo Operacional')

plt.subplot(2, 2, 3)
df['NumClientesDia'].plot.hist()
plt.title('Média Cliente por Dia')

plt.subplot(2, 2, 4)
df['CustoAquiPorCli'].plot.hist()
plt.title('Custo médio Aquisição de Clientes')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Agrupamentos
#
# Como podemos descobrir o Faturamento médio?

# %%
df['FatDia'].mean()
# Out:
# np.float64(5817.7682352941165)

# %% [markdown]
# E para descobrir o faturamento médio por Tipo de Loja?

# %%
group_df =  df.groupby(by='TipoLoja')['FatDia'].mean()
group_df
# Out:
# /tmp/ipython-input-3152164917.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# TipoLoja
# Acessórios      4566.492857
# Eletrônicos     9966.808462
# Games e Info    4190.665882
# Name: FatDia, dtype: float64

# %%
fig = plt.figure(figsize=(8, 4))
group_df.plot.bar()
plt.title('Faturamento médio porb Tipo de Loja')
plt.show()

# %% [markdown]
# **Exercício 3** Descubra o custo médio de aquisição de cliente para lojas que vendem e não vendem online.

# %%
group_df = df.groupby(by="VendeOnline")["CustoAquiPorCli"].mean()
group_df
# Out:
# /tmp/ipython-input-777938600.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# VendeOnline
# 0    3.414074
# 1    5.602500
# Name: CustoAquiPorCli, dtype: float64

# %% [markdown]
# **Exercício 4** Descubra o faturamento médio para lojas que são e não são próprias.

# %%
group_df = df.groupby(by="LojaPropria")["FatDia"].mean()
group_df
# Out:
# /tmp/ipython-input-3093658449.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# LojaPropria
# 0    5680.912593
# 1    5971.730833
# Name: FatDia, dtype: float64

# %% [markdown]
# ### Tabelas cruzadas
#
# E se quiséssemos realizar contagens de forma a considerar duas variáveis. Por exemplo, contar por Venda Online e Tipo de Loja?
#
# Neste caso, temos uma situação de análise **bivariada** de variáveis qualitativas:

# %%
ct = pd.crosstab(df['TipoLoja'], df['VendeOnline'])
ct
# Out:
# VendeOnline    0   1
# TipoLoja
# Acessórios    10  11
# Eletrônicos    8   5
# Games e Info   9   8

# %% [markdown]
# Podemos utilizar o **normalize** para normalizar para frequência relativa nas linhas, colunas ou toda a tabela cruzada.
#
# Veja mais na documentação https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html

# %%
ct = pd.crosstab(df['TipoLoja'], df['VendeOnline'], normalize='columns')
ct
# Out:
# VendeOnline          0         1
# TipoLoja
# Acessórios    0.370370  0.458333
# Eletrônicos   0.296296  0.208333
# Games e Info  0.333333  0.333333

# %% [markdown]
# Estes zeros e uns ficam estranhos, não?! Vamos renomear as categorias!

# %%
df['VendeOnline'] = df['VendeOnline'].cat.rename_categories({'0': 'Não', '1': 'Sim'})
df['LojaPropria'] = df['LojaPropria'].cat.rename_categories({'0': 'Não', '1': 'Sim'})
df.head()
# Out:
#   CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01   Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02    Acessórios  São Paulo           4048.26       16   7095.50
# 3     L03  Games e Info  São Paulo           5035.14       10   6602.59
# 4     L04  Games e Info  São Paulo           5001.69        6   3455.80
# 5     L05  Games e Info  São Paulo           4953.57        6   3515.88
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil
# 1           16.50             3.91         Não         Sim      1
# 2          145.92            10.69         Não         Sim      4
# 3           25.53             4.46         Sim         Sim      3
# 4           13.77             6.30         Sim         Não      4
# 5           13.87             2.09         Não         Não      1

# %% [markdown]
# Agora, o crosstab fica melhor:

# %%
# o parâmetro normalize pode ser index, columns ou all
cta = pd.crosstab(df['TipoLoja'], df['VendeOnline'], normalize='columns')
cta
# Out:
# VendeOnline        Não       Sim
# TipoLoja
# Acessórios    0.370370  0.458333
# Eletrônicos   0.296296  0.208333
# Games e Info  0.333333  0.333333

# %% [markdown]
# **Exercício 5** Crie:
#
# a) uma alternativa para analisar como os tipos de lojas se distribuem pelas cidades.

# %%
pd.crosstab(df['TipoLoja'], df['Cidade'])
# Out:
# Cidade        Belo Horizonte  Brasília  Rio de Janeiro  São Paulo
# TipoLoja
# Acessórios                 5         5               8          3
# Eletrônicos                2         3               5          3
# Games e Info               4         6               3          4

# %% [markdown]
# b) Dentre as lojas de Eletrônicos, qual a porcentagem das lojas que está localizada no Rio de Janeiro?

# %% [markdown]
# R: 10%

# %% [markdown]
# c) Dentre as lojas de Belo Horizonte, qual a porcentagem das lojas é do tipo Acessórios?

# %% [markdown]
# R: 5/11 (45% aproximado)

# %% [markdown]
# ### Correlação entre variáveis
#
# Podemos analisar a correlação entre as variáveis utilizando uma funcionalide da biblioteca pandas:

# %%
df[['CustoOperacional', 'NumFunc', 'FatDia', 'NumClientesDia', 'CustoAquiPorCli']].corr()
# Out:
#                   CustoOperacional   NumFunc    FatDia  NumClientesDia  \
# CustoOperacional          1.000000  0.762270  0.825869       -0.599908
# NumFunc                   0.762270  1.000000  0.816195       -0.137717
# FatDia                    0.825869  0.816195  1.000000       -0.209053
# NumClientesDia           -0.599908 -0.137717 -0.209053        1.000000
# CustoAquiPorCli          -0.024051  0.172231  0.212549        0.275020
#
#                   CustoAquiPorCli
# CustoOperacional        -0.024051
# NumFunc                  0.172231
# FatDia                   0.212549
# NumClientesDia           0.275020
# CustoAquiPorCli          1.000000

# %% [markdown]
# ou pelo uso da biblioteca seaborn:

# %%
sb.heatmap(df[['CustoOperacional', 'NumFunc', 'FatDia', 'NumClientesDia', 'CustoAquiPorCli']].corr())
# Out:
# <Axes: >

# %% [markdown]
# Ou pelo plotly express:

# %%
px.imshow(df[['CustoOperacional', 'NumFunc', 'FatDia', 'NumClientesDia', 'CustoAquiPorCli']].corr())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de440563-c9e3-41d7-89ef-ea054847c55a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de440563-c9e3-41d7-89ef-ea054847c55a")) {                    Plotly.newPlot(                        "de440563-c9e3-41d7-89ef-ea054847c55a",                        [{"coloraxis":"coloraxis","name":"0","x":["CustoOperacional","NumFunc","FatDia","NumClientesDia","CustoAquiPorCli"],"y":["CustoOperacional","NumFunc","FatDia","NumClientesDia","CustoAquiPorCli"],"z":[[1.0,0.7622702605010455,0.8258687487877684,-0.5999078361484339,-0.02405079033738699],[0.7622702605010455,1.0,0.8161948596152595,-0.13771652056314337,0.17223086721059114],[0.8258687487877684,0.8161948596152595,1.0,-0.20905346286808882,0.2125491125114237],[-0.5999078361484339,-0.13771652056314337,-0.20905346286808882,1.0,0.2750197867870454],[-0.02405079033738699,0.17223086721059114,0.2125491125114237,0.2750197867870454,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorba ...

# %% [markdown]
# ### Pivot Table
#
# E se for necessário descobrir o faturamento médio de cada tipo de loja em cada cidade?

# %%
pivot = pd.pivot_table(df, index='TipoLoja', columns='Cidade',
               values=['FatDia'], aggfunc=np.mean)

pivot
# Out:
# /tmp/ipython-input-3092357332.py:1: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#
# /tmp/ipython-input-3092357332.py:1: FutureWarning:
#
# The provided callable <function mean at 0x7f1d5be61a80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#                      FatDia
# Cidade       Belo Horizonte     Brasília Rio de Janeiro     São Paulo
# TipoLoja
# Acessórios        5501.9100  4672.704000    3734.547500   5048.966667
# Eletrônicos      10024.6950  9516.760000    9625.668000  10946.833333
# Games e Info      4219.9425  4976.503333    2493.026667   4255.862500

# %%
fig = plt.figure(figsize=(18, 5))
pivot.plot.bar()
plt.title('Faturameto médio por categoria e cidade')
plt.show()

# %%
pivot_aux = pivot.unstack().reset_index()
pivot_aux
# Out:
#    level_0          Cidade      TipoLoja             0
# 0   FatDia  Belo Horizonte    Acessórios   5501.910000
# 1   FatDia  Belo Horizonte   Eletrônicos  10024.695000
# 2   FatDia  Belo Horizonte  Games e Info   4219.942500
# 3   FatDia        Brasília    Acessórios   4672.704000
# 4   FatDia        Brasília   Eletrônicos   9516.760000
# 5   FatDia        Brasília  Games e Info   4976.503333
# 6   FatDia  Rio de Janeiro    Acessórios   3734.547500
# 7   FatDia  Rio de Janeiro   Eletrônicos   9625.668000
# 8   FatDia  Rio de Janeiro  Games e Info   2493.026667
# 9   FatDia       São Paulo    Acessórios   5048.966667
# 10  FatDia       São Paulo   Eletrônicos  10946.833333
# 11  FatDia       São Paulo  Games e Info   4255.862500

# %%
px.bar(pivot_aux, x='Cidade', y=0, color='TipoLoja', barmode='group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ffc6c7d-e64a-46d5-bef3-2ff88dcba9c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ffc6c7d-e64a-46d5-bef3-2ff88dcba9c4")) {                    Plotly.newPlot(                        "5ffc6c7d-e64a-46d5-bef3-2ff88dcba9c4",                        [{"alignmentgroup":"True","hovertemplate":"TipoLoja=Acessórios\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acessórios","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Acessórios","offsetgroup":"Acessórios","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[5501.91,4672.704,3734.5474999999997,5048.966666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"TipoLoja=Eletrônicos\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eletrônicos","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Eletrônicos","offsetgroup":"Eletrônicos","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[10024.695,9516.76,9625.668,10946.833333333334],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"TipoLoja=Games e Info\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Games e Info","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Games e Info","offsetgroup":"Games e Info","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[4219.9425,4976.503333333333,2493.0266666666666,4255.8625],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555 ...

# %%
px.bar(pivot_aux, x='Cidade', y=0, color='TipoLoja', barmode='stack')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e417ca3d-0c18-4c92-96d4-88b7ef746a19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e417ca3d-0c18-4c92-96d4-88b7ef746a19")) {                    Plotly.newPlot(                        "e417ca3d-0c18-4c92-96d4-88b7ef746a19",                        [{"alignmentgroup":"True","hovertemplate":"TipoLoja=Acessórios\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Acessórios","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Acessórios","offsetgroup":"Acessórios","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[5501.91,4672.704,3734.5474999999997,5048.966666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"TipoLoja=Eletrônicos\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eletrônicos","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Eletrônicos","offsetgroup":"Eletrônicos","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[10024.695,9516.76,9625.668,10946.833333333334],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"TipoLoja=Games e Info\u003cbr\u003eCidade=%{x}\u003cbr\u003e0=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Games e Info","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Games e Info","offsetgroup":"Games e Info","orientation":"v","showlegend":true,"textposition":"auto","x":["Belo Horizonte","Brasília","Rio de Janeiro","São Paulo"],"xaxis":"x","y":[4219.9425,4976.503333333333,2493.0266666666666,4255.8625],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555 ...

# %% [markdown]
# ### Criando colunas novas
#
# Como podemos fazer para entender o ticket médio? Temos a média de clientes por dia e o faturamento por dia. Como obter o ticket médio?

# %%
df.head()
# Out:
#   CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01   Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02    Acessórios  São Paulo           4048.26       16   7095.50
# 3     L03  Games e Info  São Paulo           5035.14       10   6602.59
# 4     L04  Games e Info  São Paulo           5001.69        6   3455.80
# 5     L05  Games e Info  São Paulo           4953.57        6   3515.88
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil
# 1           16.50             3.91         Não         Sim      1
# 2          145.92            10.69         Não         Sim      4
# 3           25.53             4.46         Sim         Sim      3
# 4           13.77             6.30         Sim         Não      4
# 5           13.87             2.09         Não         Não      1

# %%
df['TicketMedio'] = df['FatDia'] / df['NumClientesDia']
df.head()
# Out:
#   CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01   Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02    Acessórios  São Paulo           4048.26       16   7095.50
# 3     L03  Games e Info  São Paulo           5035.14       10   6602.59
# 4     L04  Games e Info  São Paulo           5001.69        6   3455.80
# 5     L05  Games e Info  São Paulo           4953.57        6   3515.88
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil  TicketMedio
# 1           16.50             3.91         Não         Sim      1   784.410909
# 2          145.92            10.69         Não         Sim      4    48.625959
# 3           25.53             4.46         Sim         Sim      3   258.620838
# 4           13.77             6.30         Sim         Não      4   250.965868
# 5           13.87             2.09         Não         Não      1   253.488104

# %% [markdown]
# E para criar categorias de custo? Abaixo de cinco mil é custo BAIXO, de cinco até oito é MÉDIO, acima de oito mil é ALTO?

# %%
def cat_custo(valor):
    if valor < 5000:
        return 'BAIXO'
    elif valor < 8000:
        return 'MEDIO'
    else:
        return 'ALTO'

# %%
df['CatCusto'] = df['CustoOperacional'].apply(cat_custo)
df.head()
# Out:
#   CodLoja      TipoLoja     Cidade  CustoOperacional  NumFunc    FatDia  \
# 1     L01   Eletrônicos  São Paulo           9893.24       20  12942.78
# 2     L02    Acessórios  São Paulo           4048.26       16   7095.50
# 3     L03  Games e Info  São Paulo           5035.14       10   6602.59
# 4     L04  Games e Info  São Paulo           5001.69        6   3455.80
# 5     L05  Games e Info  São Paulo           4953.57        6   3515.88
#
#    NumClientesDia  CustoAquiPorCli LojaPropria VendeOnline Perfil  \
# 1           16.50             3.91         Não         Sim      1
# 2          145.92            10.69         Não         Sim      4
# 3           25.53             4.46         Sim         Sim      3
# 4           13.77             6.30         Sim         Não      4
# 5           13.87             2.09         Não         Não      1
#
#    TicketMedio CatCusto
# 1   784.410909     ALTO
# 2    48.625959    BAIXO
# 3   258.620838    MEDIO
# 4   250.965868    MEDIO
# 5   253.488104    BAIXO

# %% [markdown]
# **Exercício 6** Conte quantas lojas estão em cada categoria de custo.

# %% [markdown]
# **Exercício 7** Calcule o faturamento médio por Categoria de custo.

# %% [markdown]
# **Exercício 8** Cruze a categoria de custo com o tipo de loja para contar quantas estão em cada categoria conjunta.

# %% [markdown]
# **Exercício 9** Cruze a categoria de custo com o tipo de loja, para descobrir o faturamento médio.

# %% [markdown]
# **Exercício 10** Sugira categorias para o número de funcionários e clientes. Analise o faturamento médio.

# %% [markdown]
# **Exercício 11** Crie uma coluna de região geográfica.

# %% [markdown]
# # Exportar o DataFrame para arquivos
#
# Será que conseguimos exportar o pandas DataFrame para algum arquivo?
#
# Conseguimos sim!
#
# Para exportar para Excel:

# %%
df.to_excel('lojas.xlsx')

# %% [markdown]
# e para CSV:

# %%
df.to_csv('lojas.csv')

# %% [markdown]
# # Extração de textos com PyPDF2
#
# Caso o seu PDF contenha textos ao invés de tabelas, podemos utilizar o PyPDF2.
#
# Vamos importar a biblioteca:

# %%
import PyPDF2 as pp
import urllib.request

# %% [markdown]
# Caso o import não seja realizado, descomente a próxima linha e faça a instalação

# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.12/dist-packages (2.12.1)

# %% [markdown]
# Vamos fazer o download do arquivo PDF

# %%
pdf_url = 'https://atd-insper.s3.us-east-2.amazonaws.com/aula02/ppc_computacao.pdf'

response = urllib.request.urlopen(pdf_url)

arq = open('ppc_computacao.pdf', 'wb')
arq.write(response.read())
arq.close()

# %% [markdown]
# e abrir o Arquivo

# %%
pp_reader = pp.PdfFileReader(open('ppc_computacao.pdf', 'rb'))

# %% [markdown]
# Podemos buscar informações do documento, como o número de páginas

# %%
pp_reader.documentInfo
# Out:
# {'/CreationDate': "D:20190802180410-03'00'",
#  '/ModDate': "D:20190802180410-03'00'",
#  '/Producer': 'www.ilovepdf.com'}

# %%
print(f'O arquivo tem {pp_reader.numPages} páginas')
# Out:
# O arquivo tem 247 páginas

# %% [markdown]
# Ou ler uma página específica do PDF

# %%
texto = pp_reader.getPage(0).extractText()
print(texto)
# Out:
#
#
#
#  Insper  Instituto  de Ensino  e Pesquisa
# Portaria  MEC nº 915, de 06/07/2012, D.O.U. 09/07/2012
#
#
#
#
#
#
#
# INSPER INSTITUTO DE ENSINO E PESQUISA
# PPC - PROJETO PEDAGÓGICO DO CURSO
# ENGENHA RIA DE
# COMPUTAÇÃO
#
#
#
#
#
#
#
#
#
# Aprovado pelo Colegiado de Curso em 13/06/201 9.

# %% [markdown]
# Vamos ler as 10 primeiras páginas, armazenando cada página em uma lista

# %%
lista_pg = []
for i in range(10):
    texto = pp_reader.getPage(i).extractText()
    lista_pg.append(texto)

# %% [markdown]
# Para uma melhor visualização, vamos podemos remover as quebras de linhas com **replace**

# %%
print(lista_pg[7].replace('\n', ''))
# Out:
#      7  Insper  Instituto  de Ensino  e Pesquisa  Portaria  MEC nº 915, de 06/07/2012, D.O.U. 09/07/2012  Apresentação                                                         Trata o presente do Projeto Pedagógico do Curso (PPC) do curso de graduação em ENGENHARIA DE COMPUTAÇÃO  do Insper Instituto de Ensino e Pesquisa, doravante denominado Insper.  Consubstancia -se em uma proposta curricular nas bases legais do sistema educativ o nacional e nos princípios norteadores do ensino superior, explicitados na LDB nº 9.394/96 e Resolução CNE/CES Nº 11, de 11 de Março de 2002 que institui as Diretrizes Curriculares Nacionais do curso de graduação em Engenharia, e dá outras providências.  Este documento apresenta os pressupostos teóricos, metodológicos e didático -pedagógicos estruturantes da proposta do curso em consonância com o Projeto Político -Pedagógico Institucional. Em todos os elementos estarão explicitados princípios, categorias e co nceitos que materializarão o processo de ensino e de aprendizagem destinados a todos os envolvidos nesta práxis pedagógica .

# %%
lista_pg[7].count('sistemas')
# Out:
# 0

# %% [markdown]
# **Exercício 12** Leia todas as páginas do PDF `ppc_computacao.pdf` e armazene o conteúdo em uma lista.

# %% [markdown]
# **Exercício 13** Para cada página, faça algumas limpezas:
# - Remova stop-words
# - Remova quebras de linhas
# - Remova pontuações

# %% [markdown]
# **Exercício 14** Crie uma função que retorne todas as páginas do PDF `ppc_computacao.pdf` que contém uma determinada palavra passada como parâmetro

# %% [markdown]
# **Exercício 15** Crie uma função que retorne todas as páginas onde uma palavra ou termo ocorre, além disso, deve retornar a quantidade.
#
# Dica: utilizar uma lista com tuplas ou dicionário.

# %% [markdown]
# # Alternativas:
#
# Algumas outras bibliotecas que podem ser utilizadas para extração de textos de PDFs:
#
# - tabula-py
# - tika
# - xpdf-python
# - pdftotext
# - PyMuPDF
#
# # Links interessantes da documentação do Camelot:
# - https://camelot-py.readthedocs.io/en/master/user/how-it-works.html#lattice
# - https://camelot-py.readthedocs.io/en/master/user/quickstart.html#read-the-pdf
# - https://camelot-py.readthedocs.io/en/master/user/advanced.html#detect-short-lines
# - https://camelot-py.readthedocs.io/en/master/user/faq.html#does-camelot-work-with-image-based-pdfs
